# %% [markdown]
# ### Import data table

# %%
import numpy as np
import pandas as pd

# %%
provider_2016 = pd.read_csv('Medicare_Part_D_Opioid_Prescriber_Summary_File_2016.csv')

# %%
provider_2016.shape
# Out:
# (1131550, 11)

# %%
provider_2016.sample(5)
# Out:
#                NPI NPPES Provider Last Name NPPES Provider First Name  \
# 798568  1700835956                 BANASZAK                     LLOYD
# 6521    1003839267                 O CONNOR                 CHRISTINE
# 501915  1447290663                   HAWLEY                   WILLIAM
# 768483  1679895049                    CHEUK                     JULIA
# 866061  1760590673                      LAM                   TIMOTHY
#
#         NPPES Provider ZIP Code NPPES Provider State    Specialty Description  \
# 798568                  55441.0                   MN          Family Practice
# 6521                    21202.0                   MD  Obstetrics & Gynecology
# 501915                  35960.0                   AL       Emergency Medicine
# 768483                  70039.0                   LA                  Dentist
# 866061                  98104.0                   WA                  Dentist
#
#         Total Claim Count  Opioid Claim Count  Opioid Prescribing Rate  \
# 798568                 65                 0.0                     0.00
# 6521                  172                 NaN                      NaN
# 501915                295                87.0                    29.49
# 768483                 41                 NaN                      NaN
# 866061                 38                 NaN                      NaN
#
#         Long-Acting Opioid Claim Count  Long-Acting Opioid Prescribing Rate
# 798568                             0.0                                  NaN
# 6521                               0.0                                  NaN
# 501915                             NaN                                  NaN
# 768483                             0.0                                  NaN
# 866061                             0.0                                  NaN

# %%
provider_2016.columns
# Out:
# Index(['NPI', 'NPPES Provider Last Name', 'NPPES Provider First Name',
#        'NPPES Provider ZIP Code', 'NPPES Provider State',
#        'Specialty Description', 'Total Claim Count', 'Opioid Claim Count',
#        'Opioid Prescribing Rate', 'Long-Acting Opioid Claim Count',
#        'Long-Acting Opioid Prescribing Rate'],
#       dtype='object')

# %%
# Rename the columns for further explore
provider_2016 = provider_2016.rename(columns={'NPPES Provider Last Name':'last_name', 'NPPES Provider First Name':'first_name',
                                  'NPPES Provider ZIP Code':'zip_code', 'NPPES Provider State':'state',
                                  'Specialty Description':'specialty', 'Total Claim Count':'claim_total',
                                  'Opioid Claim Count':'opioid_total', 'Opioid Prescribing Rate':'opioid_rate',
                                  'Long-Acting Opioid Claim Count':'la_opioid_count',
                                  'Long-Acting Opioid Prescribing Rate':'la_rate'})

# %%
# Remove prescriber that cannot write opioid drugs
temp = provider_2016.groupby(['specialty']).opioid_total.sum().reset_index(name='sum')
temp = temp[(temp == 0).any(1)]
temp.sample(5)
# Out:
#                                    specialty  sum
# 166                              Prosthetist  0.0
# 222  Voluntary Health or Charitable Agencies  0.0
# 36               Community/Behavioral Health  0.0
# 85                   In Home Supportive Care  0.0
# 12       Audiologist (billing independently)  0.0

# %%
white_list = list(temp.specialty.unique())
provider_2016 = provider_2016[~provider_2016['specialty'].isin(white_list)]

# %%
provider_2016.shape
# Out:
# (1131235, 11)

# %%
# reformat all the specialy names
provider_2016['specialty'] = provider_2016.specialty.str.strip().str.lower()
provider_2016.specialty.value_counts().head(10)
# Out:
# nurse practitioner                                                137822
# internal medicine                                                 133174
# dentist                                                           129650
# family practice                                                   109334
# physician assistant                                                86733
# student in an organized health care education/training program     51615
# emergency medicine                                                 47229
# obstetrics & gynecology                                            29713
# optometry                                                          28570
# psychiatry                                                         25528
# Name: specialty, dtype: int64

# %%
#remove all characters that aren't digits
provider_2016['opioid_rate'] = provider_2016['opioid_rate'].replace('%','').astype('float64')
provider_2016['la_rate'] = provider_2016['la_rate'].replace('%','').astype('float64')

# %%
provider_2016.head()
# Out:
#           NPI  last_name first_name  zip_code state           specialty  \
# 0  1003000126  ENKESHAFI    ARDALAN   21502.0    MD   internal medicine
# 1  1003000142     KHALIL     RASHID   43623.0    OH      anesthesiology
# 2  1003000167    ESCOBAR      JULIO   89403.0    NV             dentist
# 3  1003000282  BLAKEMORE      ROSIE   37243.0    TN  nurse practitioner
# 4  1003000407    GIRARDI      DAVID   15825.0    PA     family practice
#
#    claim_total  opioid_total  opioid_rate  la_opioid_count  la_rate
# 0          545          23.0         4.22              NaN      NaN
# 1         1733         941.0        54.30            165.0    17.53
# 2           49          11.0        22.45              0.0     0.00
# 3          146           NaN          NaN              0.0      NaN
# 4         2225          17.0         0.76              NaN      NaN

# %%
# Only keep all the frequent appeared specialty and update the rest to others
count = provider_2016.specialty.value_counts()
count = pd.DataFrame(count)
count = count.loc[count.specialty <100 ]
count = list(count.index)

# %%
provider_2016.specialty.replace(count, 'other', inplace=True)
provider_2016.sample(10)
# Out:
#                 NPI last_name first_name  zip_code state  \
# 972787   1851785323     REYES     JAVIER   33136.0    FL
# 237896   1215010863   MONGOLD    BRADLEY   25401.0    WV
# 1075249  1952311425    ENDRES     DONALD   99508.0    AK
# 2730     1003161068       ROY       DAWN    4765.0    ME
# 105737   1093722480      ENDE   THEODORE    8731.0    NJ
# 906892   1801087309    LESSER     LENARD   94111.0    CA
# 738002   1659349934    LARSON      JANET   56431.0    MN
# 970341   1851627376    HARIRI     MARYAM   24012.0    VA
# 263108   1235171216      SIMS      SUSAN   29412.0    SC
# 841068   1740287598    DICKEY     THOMAS   80620.0    CO
#
#                                                  specialty  claim_total  \
# 972787   student in an organized health care education/...           27
# 237896                                  emergency medicine          173
# 1075249                                     otolaryngology          149
# 2730                                    nurse practitioner         3602
# 105737                                   internal medicine         6210
# 906892                                     family practice           22
# 738002                                  nurse practitioner         7836
# 970341                                             dentist           53
# 263108                                  nurse practitioner         1341
# 841068                                 physician assistant           30
#
#          opioid_total  opioid_rate  la_opioid_count  la_rate
# 972787            0.0         0.00              0.0      NaN
# 237896           46.0        26.59              0.0     0.00
# 1075249           NaN          NaN              0.0      NaN
# 2730             20.0         0.56              0.0     0.00
# 105737          583.0         9.39            188.0    32.25
# 906892            NaN          NaN              NaN      NaN
# 738002          608.0         7.76             85.0    13.98
# 970341            0.0         0.00              0.0      NaN
# 263108           26.0         1.94              0.0     0.00
# 841068            NaN          NaN              0.0      NaN

# %%
specialty_df = provider_2016.groupby('specialty')['opioid_rate'].mean()
specialty_df = pd.DataFrame(data=specialty_df).reset_index()
specialty_df.head()
# Out:
#              specialty  opioid_rate
# 0   addiction medicine     7.451515
# 1  allergy/ immunology     0.239921
# 2   allergy/immunology     0.643378
# 3       anesthesiology    28.827551
# 4      cardiac surgery    22.294374
